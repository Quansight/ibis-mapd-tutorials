# %% [markdown]
# # Basics: Aggregation, filtering, limits

# %% [markdown]
# This tutorial is based on https://github.com/ibis-project/ibis/tree/master/docs/source/notebooks/tutorial

# %% [markdown]
# Now that you have ibis installed and connecting to your `MapD`, let's get our feet wet.

# %%
import ibis
from hosts import hosts
con = ibis.mapd.connect(**hosts['vega-demo'])

# %% [markdown]
# ## Accessing a MapD table
#
# The optional `database` parameter allows to fully qualify the table.

# %%
con.list_tables()
# Out:
# ['fec_contributions_oct', 'zipcodes_poly']

# %%
table = con.table('fec_contributions_oct')
table = con.table('fec_contributions_oct', database='mapd')
table.columns
# Out:
# ['id',
#  'amount',
#  'contrib_date',
#  'contributor_name',
#  'contributor_gender',
#  'contributor_city',
#  'contributor_state',
#  'contributor_zipcode',
#  'recipient_name',
#  'recipient_party',
#  'recipient_type',
#  'recipient_state',
#  'lat',
#  'lon']

# %% [markdown]
# ## Column selection and basic expressions
#
# Selecting columns from a table works just like pandas

# %%
col = table.lat

# alternately
col2 = table['amount']

# %% [markdown]
# Table columns are equipped with a variety of math operations and other methods to assist in writing your analytics. For example:

# %%
expr = col.log2() - 1

# %% [markdown]
# Some operations transform arrays to arrays, while others aggregate, like `sum` and `mean`:

# %%
expr2 = expr.sum()

# %% [markdown]
# The methods that are available on columns depend on the type of the column. For example, you won't see the `substr` or `upper` methods for strings on numeric columns:

# %%
table.columns
# Out:
# ['id',
#  'amount',
#  'contrib_date',
#  'contributor_name',
#  'contributor_gender',
#  'contributor_city',
#  'contributor_state',
#  'contributor_zipcode',
#  'recipient_name',
#  'recipient_party',
#  'recipient_type',
#  'recipient_state',
#  'lat',
#  'lon']

# %%
substr_expr = table.recipient_name.upper().substr(0, 2)

# %% [markdown]
# Notice that printing the expressions to the console does not actually do anything, and shows a graphical representation of the expression you've built.
#
# **Note: don't worry too much about the details of the expression tree that's outputted, it's very likely to change over time**

# %%
expr2
# Out:
# ref_0
# DatabaseTable[table]
#   name: mapd.fec_contributions_oct
#   schema:
#     id : string
#     amount : int32
#     contrib_date : date
#     contributor_name : string
#     contributor_gender : string
#     contributor_city : string
#     contributor_state : string
#     contributor_zipcode : string
#     recipient_name : string
#     recipient_party : string
#     recipient_type : string
#     recipient_state : string
#     lat : float
#     lon : float
#
# sum = Sum[double]
#   Subtract[double*]
#     left:
#       Log2[double*]
#         lat = Column[float*] 'lat' from table
#           ref_0
#     right:
#       Literal[int8]
#         1
#   where:
#     None

# %% [markdown]
# We can also execute an expression by calling `execute` on the **MapD** connection object

# %%
con.execute(col.sum().name('sum1'))
# Out:
# 368872704.0

# %% [markdown]
# There's a shortcut to make this a little more convenient in interactive use

# %% [markdown]
# ## Interactive mode
#
#
# Many Ibis expressions can be immediately executed against the database, and it may improve your productivity to have the executed for you whenever you try to print the expression in the console / IPython notebook.
#
# To do this, we have an *interactive* mode available, which can be turned on/off like so:

# %%
ibis.options.interactive = True

# %% [markdown]
# Now, any expressions you write will be executed right away

# %%
table.limit(2)
# Out:
# ref_0
# DatabaseTable[table]
#   name: mapd.fec_contributions_oct
#   schema:
#     id : string
#     amount : int32
#     contrib_date : date
#     contributor_name : string
#     contributor_gender : string
#     contributor_city : string
#     contributor_state : string
#     contributor_zipcode : string
#     recipient_name : string
#     recipient_party : string
#     recipient_type : string
#     recipient_state : string
#     lat : float
#     lon : float
#
# Limit[table]
#   table:
#     Table: ref_0
#   n:
#     2
#   offset:
#     0

# %% [markdown]
# You can select a row range with slicing syntax:

# %%
table.lat.sum().name('sum1')
# Out:
# ref_0
# DatabaseTable[table]
#   name: mapd.fec_contributions_oct
#   schema:
#     id : string
#     amount : int32
#     contrib_date : date
#     contributor_name : string
#     contributor_gender : string
#     contributor_city : string
#     contributor_state : string
#     contributor_zipcode : string
#     recipient_name : string
#     recipient_party : string
#     recipient_type : string
#     recipient_state : string
#     lat : float
#     lon : float
#
# sum1 = Sum[double]
#   lat = Column[float*] 'lat' from table
#     ref_0
#   where:
#     None

# %% [markdown]
# Don't worry about the syntax here, but expressions resulting in tabular output will come back as a pandas DataFrame by default:

# %%
table
# Out:
# DatabaseTable[table]
#   name: mapd.fec_contributions_oct
#   schema:
#     id : string
#     amount : int32
#     contrib_date : date
#     contributor_name : string
#     contributor_gender : string
#     contributor_city : string
#     contributor_state : string
#     contributor_zipcode : string
#     recipient_name : string
#     recipient_party : string
#     recipient_type : string
#     recipient_state : string
#     lat : float
#     lon : float

# %%
metrics = [table.lat.sum().name('total')]
expr = table.group_by('recipient_state').aggregate(metrics)
expr
# Out:
# ref_0
# DatabaseTable[table]
#   name: mapd.fec_contributions_oct
#   schema:
#     id : string
#     amount : int32
#     contrib_date : date
#     contributor_name : string
#     contributor_gender : string
#     contributor_city : string
#     contributor_state : string
#     contributor_zipcode : string
#     recipient_name : string
#     recipient_party : string
#     recipient_type : string
#     recipient_state : string
#     lat : float
#     lon : float
#
# Aggregation[table]
#   table:
#     Table: ref_0
#   metrics:
#     total = Sum[double]
#       lat = Column[float*] 'lat' from table
#         ref_0
#       where:
#         None
#   by:
#     recipient_state = Column[string*] 'recipient_state' from table
#       ref_0

# %% [markdown]
# ## Verbose mode and logging
#
#
# You may want to see or log all the **MapD** queries that Ibis executes under the hood. To do that, use the `options.verbose` option:

# %%
ibis.options.verbose = True

metrics = [table.lat.sum().name('total')]
expr = table.group_by('recipient_state').aggregate(metrics)
expr
# Out:
# ref_0
# DatabaseTable[table]
#   name: mapd.fec_contributions_oct
#   schema:
#     id : string
#     amount : int32
#     contrib_date : date
#     contributor_name : string
#     contributor_gender : string
#     contributor_city : string
#     contributor_state : string
#     contributor_zipcode : string
#     recipient_name : string
#     recipient_party : string
#     recipient_type : string
#     recipient_state : string
#     lat : float
#     lon : float
#
# Aggregation[table]
#   table:
#     Table: ref_0
#   metrics:
#     total = Sum[double]
#       lat = Column[float*] 'lat' from table
#         ref_0
#       where:
#         None
#   by:
#     recipient_state = Column[string*] 'recipient_state' from table
#       ref_0

# %%
queries = []
def logger(x):
    queries.append(x)
    
ibis.options.verbose_log = logger

expr.execute()
expr.execute()

queries
# Out:
# []

# %%
from __future__ import print_function
ibis.options.verbose_log = lambda x: print(x)
ibis.options.verbose = False

# %% [markdown]
# Aggregation basics
# ---
#
# One of the essential table API functions is `aggregate`. Aggregation involves the following
#
# - One or more *named* aggregate expressions, or *reductions*
# - Zero or more grouping expressions or column names
#
# This ends up working very similarly to pandas's **groupby** mechanism.
#
# Let's start with a simple reduction:

# %%
metric = table.lat.sum().name('sum1')

# %% [markdown]
# As you saw above, you can execute this immediately and obtain a value:

# %%
metric
# Out:
# ref_0
# DatabaseTable[table]
#   name: mapd.fec_contributions_oct
#   schema:
#     id : string
#     amount : int32
#     contrib_date : date
#     contributor_name : string
#     contributor_gender : string
#     contributor_city : string
#     contributor_state : string
#     contributor_zipcode : string
#     recipient_name : string
#     recipient_party : string
#     recipient_type : string
#     recipient_state : string
#     lat : float
#     lon : float
#
# sum1 = Sum[double]
#   lat = Column[float*] 'lat' from table
#     ref_0
#   where:
#     None

# %% [markdown]
# The reduced column can be more complex; for example, you could count the number of null values in a column like so:

# %%
table.lat.zeroifnull().sum().name('sum1')
# Out:
# ref_0
# DatabaseTable[table]
#   name: mapd.fec_contributions_oct
#   schema:
#     id : string
#     amount : int32
#     contrib_date : date
#     contributor_name : string
#     contributor_gender : string
#     contributor_city : string
#     contributor_state : string
#     contributor_zipcode : string
#     recipient_name : string
#     recipient_party : string
#     recipient_type : string
#     recipient_state : string
#     lat : float
#     lon : float
#
# sum1 = Sum[double]
#   ZeroIfNull[float*]
#     lat = Column[float*] 'lat' from table
#       ref_0
#   where:
#     None

# %% [markdown]
# To aggregate a table, potentially with grouping keys, we have to give the reduction a name and call `aggregate`

# %%
metric = metric.name('dest_lat')
expr = table.aggregate([metric])
result = con.execute(expr)
result
# Out:
#       dest_lat
# 0  368872704.0

# %% [markdown]
# The result here is actually a pandas DataFrame with 1 row and just the one column. We can add another metric and add a grouping key

# %%
metric2 = (table.amount + 1).log10().max().name('some_metric')

expr = table.aggregate([metric, metric2], by=['contributor_state'])
expr
# Out:
# ref_0
# DatabaseTable[table]
#   name: mapd.fec_contributions_oct
#   schema:
#     id : string
#     amount : int32
#     contrib_date : date
#     contributor_name : string
#     contributor_gender : string
#     contributor_city : string
#     contributor_state : string
#     contributor_zipcode : string
#     recipient_name : string
#     recipient_party : string
#     recipient_type : string
#     recipient_state : string
#     lat : float
#     lon : float
#
# Aggregation[table]
#   table:
#     Table: ref_0
#   metrics:
#     dest_lat = Sum[double]
#       lat = Column[float*] 'lat' from table
#         ref_0
#       where:
#         None
#     some_metric = Max[double]
#       Log10[double*]
#         Add[int64*]
#           left:
#             amount = Column[int32*] 'amount' from table
#               ref_0
#           right:
#             Literal[int8]
#               1
#       where:
#         None
#   by:
#     contributor_state = Column[string*] 'contributor_state' from table
#       ref_0

# %% [markdown]
# We provide a convenience `group_by`, a la pandas, to make this a little more composable:

# %%
expr = (table.group_by('contributor_state')
        .aggregate([metric, metric2]))
expr
# Out:
# ref_0
# DatabaseTable[table]
#   name: mapd.fec_contributions_oct
#   schema:
#     id : string
#     amount : int32
#     contrib_date : date
#     contributor_name : string
#     contributor_gender : string
#     contributor_city : string
#     contributor_state : string
#     contributor_zipcode : string
#     recipient_name : string
#     recipient_party : string
#     recipient_type : string
#     recipient_state : string
#     lat : float
#     lon : float
#
# Aggregation[table]
#   table:
#     Table: ref_0
#   metrics:
#     dest_lat = Sum[double]
#       lat = Column[float*] 'lat' from table
#         ref_0
#       where:
#         None
#     some_metric = Max[double]
#       Log10[double*]
#         Add[int64*]
#           left:
#             amount = Column[int32*] 'amount' from table
#               ref_0
#           right:
#             Literal[int8]
#               1
#       where:
#         None
#   by:
#     contributor_state = Column[string*] 'contributor_state' from table
#       ref_0

# %% [markdown]
# You can also group by named column expressions

# %%
keys = [table.contrib_date.day().name('_day'), 'contributor_state']

expr = table.group_by(keys).aggregate([metric])

# Top 10 by double_total, more on this later
expr.sort_by([('dest_lat', False)]).limit(10)
# Out:
# ref_0
# DatabaseTable[table]
#   name: mapd.fec_contributions_oct
#   schema:
#     id : string
#     amount : int32
#     contrib_date : date
#     contributor_name : string
#     contributor_gender : string
#     contributor_city : string
#     contributor_state : string
#     contributor_zipcode : string
#     recipient_name : string
#     recipient_party : string
#     recipient_type : string
#     recipient_state : string
#     lat : float
#     lon : float
#
# ref_1
# Aggregation[table]
#   table:
#     Table: ref_0
#   metrics:
#     dest_lat = Sum[double]
#       lat = Column[float*] 'lat' from table
#         ref_0
#       where:
#         None
#   by:
#     _day = ExtractDay[int32*]
#       contrib_date = Column[date*] 'contrib_date' from table
#         ref_0
#     contributor_state = Column[string*] 'contributor_state' from table
#       ref_0
#
# ref_2
# Selection[table]
#   table:
#     Table: ref_1
#   sort_keys:
#     SortKey[array-sort]
#       expr:
#         dest_lat = Column[double*] 'dest_lat' from table
#           ref_1
#       ascending:
#         False
#
# Limit[table]
#   table:
#     Table: ref_2
#   n:
#     10
#   offset:
#     0

# %% [markdown]
# In most cases, an aggregation by itself can be evaluated:

# %%
table.lat.mean()
# Out:
# ref_0
# DatabaseTable[table]
#   name: mapd.fec_contributions_oct
#   schema:
#     id : string
#     amount : int32
#     contrib_date : date
#     contributor_name : string
#     contributor_gender : string
#     contributor_city : string
#     contributor_state : string
#     contributor_zipcode : string
#     recipient_name : string
#     recipient_party : string
#     recipient_type : string
#     recipient_state : string
#     lat : float
#     lon : float
#
# mean = Mean[double]
#   lat = Column[float*] 'lat' from table
#     ref_0
#   where:
#     None

# %% [markdown]
# This can also be done in simple cases along with `group_by`:

# %%
# TODO: resolve aggregation name
table.group_by('contributor_state').lat.mean().compile()
# Out:
# 'SELECT "contributor_state", avg("lat") AS mean(lat)\nFROM mapd.fec_contributions_oct\nGROUP BY contributor_state'

# %% [markdown]
# Many reduction functions have a default expression name, unlike many other Ibis expressions (for now!), to make some common analyses easier:

# %%
# TODO: resolve aggregation name
d = table.lat

(table.group_by('contributor_state')
 .aggregate([
     d.sum().name('sum1'), 
     d.mean().name('mean1'), 
     d.min().name('min1'), 
     d.max().name('max1')
 ]))
# Out:
# ref_0
# DatabaseTable[table]
#   name: mapd.fec_contributions_oct
#   schema:
#     id : string
#     amount : int32
#     contrib_date : date
#     contributor_name : string
#     contributor_gender : string
#     contributor_city : string
#     contributor_state : string
#     contributor_zipcode : string
#     recipient_name : string
#     recipient_party : string
#     recipient_type : string
#     recipient_state : string
#     lat : float
#     lon : float
#
# Aggregation[table]
#   table:
#     Table: ref_0
#   metrics:
#     sum1 = Sum[double]
#       lat = Column[float*] 'lat' from table
#         ref_0
#       where:
#         None
#     mean1 = Mean[double]
#       lat = Column[float*] 'lat' from table
#         ref_0
#       where:
#         None
#     min1 = Min[float]
#       lat = Column[float*] 'lat' from table
#         ref_0
#       where:
#         None
#     max1 = Max[float]
#       lat = Column[float*] 'lat' from table
#         ref_0
#       where:
#         None
#   by:
#     contributor_state = Column[string*] 'contributor_state' from table
#       ref_0

# %% [markdown]
# Of course, for this _particular_ case you can always use `summary`

# %%
# TODO
# table.group_by('origin_name').dest_lat.summary()

# %% [markdown]
# ## Filtering
#
# Filtering tables works similarly to pandas

# %%
table.aggregate([table.amount.max().name('weatherdelay_max'),
                 table.contrib_date.day().min().name('flight_year_min'),
                 table.contrib_date.month().max().name('flight_month_max'),])
# Out:
# ref_0
# DatabaseTable[table]
#   name: mapd.fec_contributions_oct
#   schema:
#     id : string
#     amount : int32
#     contrib_date : date
#     contributor_name : string
#     contributor_gender : string
#     contributor_city : string
#     contributor_state : string
#     contributor_zipcode : string
#     recipient_name : string
#     recipient_party : string
#     recipient_type : string
#     recipient_state : string
#     lat : float
#     lon : float
#
# Aggregation[table]
#   table:
#     Table: ref_0
#   metrics:
#     weatherdelay_max = Max[int32]
#       amount = Column[int32*] 'amount' from table
#         ref_0
#       where:
#         None
#     flight_year_min = Min[int32]
#       day = ExtractDay[int32*]
#         contrib_date = Column[date*] 'contrib_date' from table
#           ref_0
#       where:
#         None
#     flight_month_max = Max[int32]
#       month = ExtractMonth[int32*]
#         contrib_date = Column[date*] 'contrib_date' from table
#           ref_0
#       where:
#         None

# %%
# TODO: resolve aggregation name
table.count().name('count1')
# Out:
# ref_0
# DatabaseTable[table]
#   name: mapd.fec_contributions_oct
#   schema:
#     id : string
#     amount : int32
#     contrib_date : date
#     contributor_name : string
#     contributor_gender : string
#     contributor_city : string
#     contributor_state : string
#     contributor_zipcode : string
#     recipient_name : string
#     recipient_party : string
#     recipient_type : string
#     recipient_state : string
#     lat : float
#     lon : float
#
# count1 = Count[int64]
#   Table: ref_0
#   where:
#     None

# %%
# TODO: resove aggregation name
table[table.amount > 50].count().name('count1')
# Out:
# ref_0
# DatabaseTable[table]
#   name: mapd.fec_contributions_oct
#   schema:
#     id : string
#     amount : int32
#     contrib_date : date
#     contributor_name : string
#     contributor_gender : string
#     contributor_city : string
#     contributor_state : string
#     contributor_zipcode : string
#     recipient_name : string
#     recipient_party : string
#     recipient_type : string
#     recipient_state : string
#     lat : float
#     lon : float
#
# ref_1
# Selection[table]
#   table:
#     Table: ref_0
#   predicates:
#     Greater[boolean*]
#       left:
#         amount = Column[int32*] 'amount' from table
#           ref_0
#       right:
#         Literal[int32]
#           50
#
# count1 = Count[int64]
#   Table: ref_1
#   where:
#     None

# %% [markdown]
# Filters can be composed using & (and), | (or), and other logical array operators

# %%
# TODO: resolve aggregation name
cond1 = table.amount > 50
cond2 = table.contrib_date.day().between(2, 7)
table[cond1 | cond2].count().name('count1')
# Out:
# ref_0
# DatabaseTable[table]
#   name: mapd.fec_contributions_oct
#   schema:
#     id : string
#     amount : int32
#     contrib_date : date
#     contributor_name : string
#     contributor_gender : string
#     contributor_city : string
#     contributor_state : string
#     contributor_zipcode : string
#     recipient_name : string
#     recipient_party : string
#     recipient_type : string
#     recipient_state : string
#     lat : float
#     lon : float
#
# ref_1
# Selection[table]
#   table:
#     Table: ref_0
#   predicates:
#     Or[boolean*]
#       left:
#         Greater[boolean*]
#           left:
#             amount = Column[int32*] 'amount' from table
#               ref_0
#           right:
#             Literal[int32]
#               50
#       right:
#         Between[boolean*]
#           day = ExtractDay[int32*]
#             contrib_date = Column[date*] 'contrib_date' from table
#               ref_0
#           lower_bound:
#             Literal[int8]
#               2
#           upper_bound:
#             Literal[int8]
#               7
#
# count1 = Count[int64]
#   Table: ref_1
#   where:
#     None

# %% [markdown]
# There's a `filter` function that allows you to pass a list of conditions (that are all required to hold):

# %%
# TODO: resolve aggregation name
table.filter([cond1, cond2]).count().name('count1')
# Out:
# ref_0
# DatabaseTable[table]
#   name: mapd.fec_contributions_oct
#   schema:
#     id : string
#     amount : int32
#     contrib_date : date
#     contributor_name : string
#     contributor_gender : string
#     contributor_city : string
#     contributor_state : string
#     contributor_zipcode : string
#     recipient_name : string
#     recipient_party : string
#     recipient_type : string
#     recipient_state : string
#     lat : float
#     lon : float
#
# ref_1
# Selection[table]
#   table:
#     Table: ref_0
#   predicates:
#     Greater[boolean*]
#       left:
#         amount = Column[int32*] 'amount' from table
#           ref_0
#       right:
#         Literal[int32]
#           50
#     Between[boolean*]
#       day = ExtractDay[int32*]
#         contrib_date = Column[date*] 'contrib_date' from table
#           ref_0
#       lower_bound:
#         Literal[int8]
#           2
#       upper_bound:
#         Literal[int8]
#           7
#
# count1 = Count[int64]
#   Table: ref_1
#   where:
#     None

# %% [markdown]
# Note this is the same as &-ing the boolean conditions yourself:

# %%
# TODO: resove aggregation name
table[cond1 & cond2].count().name('count1')
# Out:
# ref_0
# DatabaseTable[table]
#   name: mapd.fec_contributions_oct
#   schema:
#     id : string
#     amount : int32
#     contrib_date : date
#     contributor_name : string
#     contributor_gender : string
#     contributor_city : string
#     contributor_state : string
#     contributor_zipcode : string
#     recipient_name : string
#     recipient_party : string
#     recipient_type : string
#     recipient_state : string
#     lat : float
#     lon : float
#
# ref_1
# Selection[table]
#   table:
#     Table: ref_0
#   predicates:
#     Greater[boolean*]
#       left:
#         amount = Column[int32*] 'amount' from table
#           ref_0
#       right:
#         Literal[int32]
#           50
#     Between[boolean*]
#       day = ExtractDay[int32*]
#         contrib_date = Column[date*] 'contrib_date' from table
#           ref_0
#       lower_bound:
#         Literal[int8]
#           2
#       upper_bound:
#         Literal[int8]
#           7
#
# count1 = Count[int64]
#   Table: ref_1
#   where:
#     None

# %% [markdown]
# ## Limits
#
#
# Like in SQL, the `limit` function selects the indicated numbers of rows from the beginning of a table's result set

# %%
table.limit(2)
# Out:
# ref_0
# DatabaseTable[table]
#   name: mapd.fec_contributions_oct
#   schema:
#     id : string
#     amount : int32
#     contrib_date : date
#     contributor_name : string
#     contributor_gender : string
#     contributor_city : string
#     contributor_state : string
#     contributor_zipcode : string
#     recipient_name : string
#     recipient_party : string
#     recipient_type : string
#     recipient_state : string
#     lat : float
#     lon : float
#
# Limit[table]
#   table:
#     Table: ref_0
#   n:
#     2
#   offset:
#     0
